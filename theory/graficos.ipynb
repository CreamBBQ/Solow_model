# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
s = 0.5
delta = 0.3
n = 0.3
k_ast = (delta/(n+delta))**(1/(1-delta))
y_ast = (delta/(n+delta))**(delta/(1-delta))

# %%
k = np.linspace(0,10,100)
y = k**delta
save = s*y
dep = (n+delta)*k
fig = plt.figure(figsize=(10,5))
plt.plot(k,y)
plt.plot(k,save)
plt.plot(k,dep)
plt.show()
